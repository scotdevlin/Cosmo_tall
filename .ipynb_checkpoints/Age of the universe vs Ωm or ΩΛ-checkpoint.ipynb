# %%
# First let's set up our packages
import numpy as np
from matplotlib import pyplot as plt
from scipy import integrate

# And set some constants
c = 299792.458 # km/s (speed of light)

H0kmsmpc = 70.  # Hubble constant in km/s/Mpc
H0s = H0kmsmpc * 3.2408e-20 # H0 in inverse seconds is H0 in km/s/Mpc * (3.2408e-20 Mpc/km)
H0y = H0s * 3.154e7 * 1.e9 # H0 in inverse Giga years is H0 in inverse seconds * (3.154e7 seconds/year) * (1e9 years / Giga year)
print('Hubble time = ',1/H0y,'Gyr')

# Let's format that to a more appropriate number of significant figures.  
# The first % means put the variable here.  The .2f means make it a float with 2 decimal places.
print('Hubble time = %.2f Gyr'%(1/H0y))
# Out:
# Hubble time =  13.976165695516954 Gyr
# Hubble time = 13.98 Gyr

# %% [markdown]
# No Or

# %%
ol = 0.7
ok = 1-om-ol

om_arr = np.arange(0,2,0.1)
age_Gyr_arr = []                        # create an empty array


def adotinv(a,om,ol,ok):
    adot = a*(np.sqrt((om * a**(-3)) + (ok * a**(-2)) + ol))  # EQUATION 9 = adot/H 
    return 1.0/adot

for om in om_arr:
    t_lookback_Gyr = integrate.quad(adotinv, 0, 1, args=(om,ol,ok))  # integral limits in green, they are between what values of a you want to know the time for
    age_Gyr = t_lookback_Gyr[0]/H0y
    age_Gyr_arr.append(age_Gyr)                                                # Append age_Gyr to age_Gyr_arr
    print('if Ωm = %.2f, age of the universe is %.2f Gyr'%(om,age_Gyr))

# Print age_Gyr_arr
print(age_Gyr_arr)

# Uncomment these commands to plot this new model (note I've added a label that can be used in the legend)
#plt.plot(t_lookback_Gyr,a_arr,label='(ΩM,ΩΛ)(ΩM,ΩΛ)(\Omega_M,\Omega_\Lambda)=(%.2f,%.2f)'%(om,ol))
plt.plot(om_arr,age_Gyr_arr,label='(ΩΛ)=(%.2f)'%(ol))
plt.xlabel('om_arr')
plt.ylabel('Age of Universe (Gyr)')
plt.legend(loc='lower right',frameon=False)
plt.show()
# Out:
# if Ωm = 0.00, age of the universe is nan Gyr
# if Ωm = 0.10, age of the universe is nan Gyr
# if Ωm = 0.20, age of the universe is nan Gyr
# if Ωm = 0.30, age of the universe is nan Gyr
# if Ωm = 0.40, age of the universe is nan Gyr
# if Ωm = 0.50, age of the universe is nan Gyr
# if Ωm = 0.60, age of the universe is nan Gyr
# if Ωm = 0.70, age of the universe is nan Gyr
# if Ωm = 0.80, age of the universe is nan Gyr
# if Ωm = 0.90, age of the universe is nan Gyr
# if Ωm = 1.00, age of the universe is 23.20 Gyr
# if Ωm = 1.10, age of the universe is 17.29 Gyr
# if Ωm = 1.20, age of the universe is 14.62 Gyr
# if Ωm = 1.30, age of the universe is 12.97 Gyr
# if Ωm = 1.40, age of the universe is 11.80 Gyr
# if Ωm = 1.50, age of the universe is 10.91 Gyr
# if Ωm = 1.60, age of the universe is 10.21 Gyr
# if Ωm = 1.70, age of the universe is 9.63 Gyr
# if Ωm = 1.80, age of the universe is 9.14 Gyr
# if Ωm = 1.90, age of the universe is 8.72 Gyr
# [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 23.204835989979657, 17.292234255776854, 14.624672372003014, 12.96965135936419, 11.800485871809403, 10.912595334091263, 10.206195436474097, 9.625559004806304, 9.136603910077643, 8.717074257032456]
# C:\Users\ScotDevlin\AppData\Local\Temp\ipykernel_14812\3883416102.py:9: RuntimeWarning: invalid value encountered in sqrt
#   adot = a*(np.sqrt((om * a**(-3)) + (ok * a**(-2)) + ol))  # EQUATION 9 = adot/H
# C:\Users\ScotDevlin\AppData\Local\Temp\ipykernel_14812\3883416102.py:13: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   t_lookback_Gyr = integrate.quad(adotinv, 0, 1, args=(om,ol,ok))  # integral limits in green, they are between what values of a you want to know the time for
